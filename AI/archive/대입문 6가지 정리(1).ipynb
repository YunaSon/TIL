# %% [markdown]
# # 1

# %%
 a = 1  # 가장 기본적인 대입문 이름을 붙이는 것을 대입한다고 한다

# %%
CON = 1   # 파이썬에는 상수가 없다, 상수를 대입문으로 사용할 경우 대문자로 사용하여 상수를 만들 수 있다.

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'a = 1  # 가장 기본적인 대입문 이름을 붙이는 것을 대입한다고 한다 ',
#   'CON = 1   # 파이썬에는 상수가 없다, 상수를 대입문으로 사용할 경우 대문자로 사용하여 상수를 만들 수 있다. ',
#   'globals',
#   'globals()'],
#  '_oh': {3: <function globals()>},
#  '_dh': ['/home/ai47/다운로드'],
#  'In': ['',
#   'a = 1  # 가장 기본적인 대입문 이름을 붙이는 것을 대입한다고 한다 ',
#   'CON = 1   # 파이썬에는 상수가 없다, 상수를 대입문으로 사용할 경우 대문자로 사용하여 상수를 만들 수 있다. ',
#   'globals',
#   'globals()'],
#  'Out': {3: <function globals()>},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f85feedc490>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7f85fd272150>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7f85fd272150>,
# ...

# %% [markdown]
# # 2

# %%
a=b=1

# %%
a
# Out:
# 1

# %%
b
# Out:
# 1

# %%
a=2

# %%
a
# Out:
# 2

# %%
b
# Out:
# 1

# %%
a=b=[1,2,3]

# %%
a.append(4)

# %%
b
# Out:
# [1, 2, 3, 4]

# %%
a =1

# %%
id(a)
# Out:
# 94095416636192

# %%
a=2

# %%
id(a)
# Out:
# 94095416636224

# %%
b=2

# %%
id(b)
# Out:
# 94095416636224

# %%
a==b
# Out:
# True

# %%
a is b   #메모리 영역까지 비교하여 서로 같은지 확인
# Out:
# True

# %%
a = 256

# %%
b = 256

# %%
a==b
# Out:
# True

# %%
a is b
# Out:
# True

# %% [markdown]
# -5 ~ 256 까지는 메모리를 재사용

# %% [markdown]
# # 3

# %%
a = 1

# %%
a += 1   # a가 이전에 정의 되어 있어야 한다. 그렇지 않으면 네임 에러가 난다.

# %%
++a   # 다른 언어에서는 a = a+1
# Out:
# 2

# %% [markdown]
# # 4

# %%
x,y = 1,2,

# %%
x, y = [1,2]

# %%
x,y ={3,1}   # 집합에서는 순서가 없다. 순서가 낮은 순서로 뽑힌다.

# %%
x
# Out:
# 1

# %%
x, y = {'a':1,'b':2}

# %%
x
# Out:
# 'a'

# %%
x,*y =1,2,3    # 쌍이 맞지 않을 경우 *을 사용하여 나머지 부분을 할당할 수 있다 .

# %%
x
# Out:
# 1

# %%
x,*y='12345'

# %%
y
# Out:
# ['2', '3', '4', '5']

# %%
*x = '12345'
# Out:
#   File "<ipython-input-62-9dd94e270403>", line 4
# SyntaxError: starred assignment target must be in a list or tuple

# %%
*x, = '12345'

# %%
x
# Out:
# ['1', '2', '3', '4', '5']

# %%
b =[1,2,3,4,5,6]

# %%
def aa(*a):
    return a

# %%
aa(1,1)
# Out:
# (1, 1)

# %%
aa(b)
# Out:
# ([1, 2, 3, 4, 5, 6],)

# %%
aa(*b)    # arguement 와   parameter 에 * 를 사용하여 뭉탱이로 넣지 않을 수 있다
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
c = {'a':1, 'b':2}

# %%
aa(*c)   # 키가 중요함으로 키가 출력
# Out:
# ('a', 'b')

# %%
def bb(**b):
    return b

# %%
bb(**c)
# Out:
# {'a': 1, 'b': 2}

# %%
bb(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-bbdc66120137> in <module>
# ----> 1 bb(c)
#
# TypeError: bb() takes 0 positional arguments but 1 was given

# %%
{'b':1, 'a':2, 'b':3}   # 중복 입력하게 되면 마지막에 입력된 값이 덮어서 저장, 키 기반이기 때문에 순서는 변하지 않음
# Out:
# {'b': 3, 'a': 2}

# %%
x = {'a':1, 'c':2}
y = {'a':2, 'b':1}

# %%
z = {**x,**y}

# %%
z
# Out:
# {'a': 2, 'c': 2, 'b': 1}

# %%
{[1],2,3}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-d7876f8d2255> in <module>
# ----> 1 {[1],2,3}
#
# TypeError: unhashable type: 'list'

# %%
{(1,),2,3}
# Out:
# {(1,), 2, 3}

# %%
{(1, [1,2]),2,3}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-48f11d50863a> in <module>
# ----> 1 {(1, [1,2]),2,3}
#
# TypeError: unhashable type: 'list'

# %%
{1:'1'}    # 해시블 한 것
# Out:
# {1: '1'}

# %% [markdown]
# # 6    global, nonlocal  두꺼운 키워드( 핵심 키워드)

# %% [markdown]
# 4일차 수업에 실습한 것    단순문에서 찾아 볼 수 있다.

# %% [markdown]
# 예외처리문

# %%
try:
except: # 필수 2가지 
#else:
#finally
# Out:
#   File "<ipython-input-101-357d019a4dd7>", line 2
#     except: # 필수 2가지
#          ^
# IndentationError: expected an indented block

# %%
try:
    1/0
except:
    print('error')
else:
    print('1')
finally:
    print('end')  # error 가 나도 안나도 실행된다.  파이썬은 EAFP 철학을 갖고 있다.
# Out:
# error
