# %% [markdown]
# # 대입문
# # 조건문
# # 반복문

# %% [markdown]
# # 선언문 :   함수 클라스에서만 사용가능

# %%
def x():
    return 1

# %%
type(x)
# Out:
# function

# %%
x
# Out:
# <function __main__.x()>

# %%
len   # / 포지션 방식
# Out:
# <function len(obj, /)>

# %%
import builtins

# %%
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
sum([1,2,3],2)
# Out:
# 8

# %%
sum([1,2,3],start=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-5c48d90f2310> in <module>
# ----> 1 sum([1,2,3],start=1)
#
# TypeError: sum() takes no keyword arguments

# %%
sum([1,2,3])
# Out:
# 6

# %%
all([1,2,3,4])
# Out:
# True

# %%
all({1,'',3})
# Out:
# False

# %%
def x():
    print (1)  # print 로 사용하는 경우 out 으로 나오지 않음 
    return None   # Return None 값이 항상 들어가 있음

# %%
x()
# Out:
# 1

# %%
def x():
    return 1

# %%
x()   # return 있는 경우 out으로 나옴
# Out:
# 1

# %%
t = x()

# %%
t
# Out:
# 1

# %%
a =[1,2,3]

# %%
a.append(4)

# %%
x=sum

# %%
x
# Out:
# <function sum(iterable, start=0, /)>

# %%
x([1,2])
# Out:
# 3

# %%
sum=1

# %%
# %whos
# Out:
# Variable   Type                          Data/Info
# --------------------------------------------------
# a          list                          n=4
# builtins   module                        <module 'builtins' (built-in)>
# sum        int                           1
# t          int                           1
# x          builtin_function_or_method    <built-in function sum>

# %%
del sum   # del 문으로 지운다

# %%
del(x)   # del 함수로 지운다

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# a          list      n=4
# builtins   module    <module 'builtins' (built-in)>
# t          int       1

# %%
print = 1

# %%
print(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-e9b8b06bc415> in <module>
# ----> 1 print(1)
#
# TypeError: 'int' object is not callable

# %%
del print

# %%
print (1)
# Out:
# 1

# %%
t = print

# %%
t(1)
# Out:
# 1

# %% [markdown]
# # encapulation

# %%
def xx():
    def yy():
        return 1 
    return2

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-b9dc5cdcc868> in <module>
# ----> 1 xx(xxx)
#
# NameError: name 'xxx' is not defined
