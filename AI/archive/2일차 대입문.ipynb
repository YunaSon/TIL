# %%
a =[1]

# %%
b =[1,]  # 값을 계속 추가할 수 있음, 명확하게

# %%
c = (1) # 우선 순위가 높은 값

# %%
d = (1, )

# %%
e = 1,

# %%
type(e)
# Out:
# tuple

# %%
f = 1,2,3

# %%
type(f)
# Out:
# tuple

# %%
x,y = 2,3

# %% [markdown]
# # unpacking

# %%
*x,y =1,2,3

# %%
y
# Out:
# 3

# %% [markdown]
# # 대입문  7 가지

# %%
a=1

# %%
a +=1

# %%
a
# Out:
# 2

# %%
x = y = 2
