# %%
t = print

# %% [markdown]
# 클로저 기법

# %%
def x(n):
    def y(a):
        return a+n
    return y

# %%
x()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-08f9d0828de0> in <module>
# ----> 1 x()
#
# TypeError: x() missing 1 required positional argument: 'n'

# %%
x(1)(1)
# Out:
# 2

# %%
t= x(3)

# %%
t(4)
# Out:
# 7

# %%
def x(n,*,b):
    def y(a,x=1):
        return a+n+b+x
    return y

# %%
x(3,b=1)(4)
# Out:
# 9

# %%
import matplotlib.pyplot as plt

# %%
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
plt.plot((3,1,5,6))      # ';'  사용시 out 이 나오지 않는다 그래프만 보여지게 하기 위해서 사용 ,

# %%
plt.plot(1, 90, 'bo');

# %%
plt.plot(1)
