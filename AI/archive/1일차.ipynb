# %% [markdown]
# # 생산성 굿

# %% [markdown]
# ---

# %% [markdown]
# # 동시에 혼용해서 사용 가능

# %% [markdown]
# # GLUE LANGUAGE

# %% [markdown]
# # C++ 기반 프로그램 ->CPython

# %% [markdown]
# # easy

# %%
1+1
# Out:
# 2

# %% [markdown]
# # general purpose

# %% [markdown]
# # 최대 단점 모바일 지원에 약점

# %% [markdown]
# # 목적은 딥러닝

# %% [markdown]
# # 인공지능 = 알고리즘능력 + 씨언어 + 파이썬

# %% [markdown]
# # 씨언어나 자바로  시스템화 해야 돈이 됨

# %% [markdown]
# # 파이썬은 인공지능을 개발할 수 있는 기본적인 도구

# %%
1+1
# Out:
# 2

# %% [markdown]
# 인터프리터

# %%
1-1
# Out:
# 0

# %% [markdown]
# 곱하기

# %%
2*5
# Out:
# 10

# %% [markdown]
# 나누기

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
10%3
# Out:
# 1

# %% [markdown]
# ---

# %%
2**3
# Out:
# 8

# %%
a = 2**3

# %%
a
# Out:
# 8

# %% [markdown]
# a 를 식별자 정의 이름을 붙이는 규칙이 존재

# %%
1a
# Out:
#   File "<ipython-input-12-3051ded84a5c>", line 1
#     1a
#      ^
# SyntaxError: invalid syntax

# %%
a1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e6d9715dfa5f> in <module>
# ----> 1 a1
#
# NameError: name 'a1' is not defined

# %%
a-3
# Out:
# 5

# %%
a1 = 5

# %%
문근영 = 5

# %%
문근영
# Out:
# 5

# %% [markdown]
# 이름 붙이는 규칙 3 가지 존재

# %%
a = 1_000

# %%
b = 1_0

# %%
c = 1.0

# %%
type(c)
# Out:
# float

# %%
e = .3

# %%
e
# Out:
# 0.3

# %%
f=3.

# %%
f
# Out:
# 3.0

# %%
g = 3e2

# %%
g
# Out:
# 300.0

# %%
h=3e-2

# %%
h
# Out:
# 0.03

# %% [markdown]
# 좌변 식별자 우변 식 또는 값

# %% [markdown]
# https://docs.python.org/ko/3/glossary.html
# 파이썬 설명서 링크 - 용어집 - expression (표현식) <- 레퍼런스 임
# 식 정의: 하나의 결과 값을 만드는 것을 식이라 한다. 1+1
# 최종 결과를 값이라 한다. 예시 3

# %% [markdown]
# 파이썬에서 사용하는 수 4 가지
# 1. int = 정수 -> 2진법 b, 8진법 o, 16진법 x
# 2. float = . 또는 e 붙이는 부동소수 ie).과 e는 리터럴
# 3. complex = 복소수 j 또는 J
# 4. bool 0과 1을 정의함 true = 정수 1 을 뜻 함

# %%
0b1
# Out:
# 1

# %%
0o3
# Out:
# 3

# %%
0xf
# Out:
# 15

# %% [markdown]
# 리터럴 특수한 문자나 기호로 사용되어 숫자로 표현됨

# %%
p = True

# %%
p
# Out:
# True

# %%
type(p)
# Out:
# bool

# %%
0.1 +0.1 + 0.1
# Out:
# 0.30000000000000004

# %% [markdown]
# 컴퓨터 언어는 0과 1로 표현하기 때문에 위와 같은 값이 나옴. 소수를 사용할 경우 주의해야 함.

# %%
type(a)
# Out:
# int

# %%
a
# Out:
# 1000

# %%
b
# Out:
# 10

# %% [markdown]
# # 습득하기 위해서 복습은 필수

# %%
x = b"a"

# %% [markdown]
# 아스키 코드로 표현하기 위해서 b를 붙인다
# 아스키 코드?
# 파이썬 3에서는 u

# %%
x = "문근영\n예뻐요"

# %%
x
# Out:
# '문근영\n예뻐요'

# %%
print(x)
# Out:
# 문근영
# 예뻐요

# %%
3 + 'anc'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-db5295a44dcd> in <module>
# ----> 1 3 + 'anc'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
3 * "anc"
# Out:
# 'ancancanc'

# %% [markdown]
# 데이터 타입에 따라서 연산이 달라진다

# %%
'A' + 'B'
# Out:
# 'AB'

# %% [markdown]
# 문자끼리 연산은 더하기만 가능하다.

# %%
type(x)
# Out:
# str

# %% [markdown]
# 문자는 개별 또는 집합으로 인식
# 문자에서 순서가 중요한 집합체를 시퀀스라 한다.

# %%
b = b'You are beautiful'

# %%
b[5:7]
# Out:
# b're'

# %%
d=[1,'2',[3]]

# %%
type(d)
# Out:
# list

# %%
b[4:]
# Out:
# b'are beautiful'

# %%
b[0]
# Out:
# '문'

# %%
b[2]
# Out:
# '영'

# %%
b[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-69-f1ec67acb3ef> in <module>
# ----> 1 b[3]
#
# IndexError: string index out of range

# %%
   b[-1]
# Out:
# '영'

# %%
b[-3]
# Out:
# '문'

# %% [markdown]
# # 집합문자 중에서 뽑는 것을 indexing 동시에 한개 이상 뽑아내는 것 slicing

# %%
b[0:5]
# Out:
# '문근영'

# %%
b[:5]
# Out:
# '문근영'

# %%
b[-3:]
# Out:
# '좋아요'

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # 시퀀스

# %% [markdown]
# 시퀀스 타입이면 인덱싱과 스라이싱이 가능

# %%
y={1,2,3,1,'1',1,123}

# %%
y
# Out:
# {1, '1', 123, 2, 3}

# %% [markdown]
# immutuble/ mutuble,  homegenius/heterogenius, 시퀀스/넌시퀀스,
