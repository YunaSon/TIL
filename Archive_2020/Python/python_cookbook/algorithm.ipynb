# %% [markdown]
# 검색, 정렬, 순서, 여과 등에 대한 질문에 종종 의문이 생긴다.
# 일반적인 자료구조와 알고리즘 그리고 데이터에 대한 내용을 다룬다.

# %% [markdown]
# ## 1.1 시퀀스를 개별 변수로 나누기
#
# 문제: N개의 요소를 가진 튜틀이나 시퀀스가 있다. 이를 변수 N개로 나누어야 한다.

# %%
p = (4, 5)
x, y = p
x
# Out:
# 4

# %%
data = ['ACME', 50, 91.1, (2012, 12, 21)]
name, shares, price, date = data
date
# Out:
# (2012, 12, 21)

# %% [markdown]
# 토론
#
# 언패킹(unpacking)은 사실 튜플이나 리스트뿐아니라 순환 가능한 객체에 적용 가능하다.
#
#
# 순환가능한 객체: 문자열, 파일 이터레이터, 제너리이터, 튜플, 리스트, 딕셔너리

# %%
s = 'hello'
a,b,c,d,e = s
a
# Out:
# 'h'

# %%
mydict = {"name": "son", "age": 33}
a,b = mydict.items()
c,d = mydict

# %%
a
# Out:
# ('name', 'son')

# %%
c
# Out:
# 'name'

# %% [markdown]
# ## 1.2 임의 순환체의 요소 나누기
#
# 문제: 순환체를 언패킹하려는데 요소가 N개 이상 포함되어 "값이 너무 많습니다."라는 예외가 발생한다.

# %%
def drop_first_last(grades):
    first, *middle, last = grades
    return avg(middle)

# %%
record = ('Dave', 'dave@example.com', '775-555-1212', '847-555-1212')
name, email, *phone_numbers = record

# %%
email
# Out:
# 'dave@example.com'

# %%
*trailing, current = [10, 8, 7, 1, 9, 5, 10, 3]
trailing
# Out:
# [10, 8, 7, 1, 9, 5, 10]

# %%
current
# Out:
# 3

# %% [markdown]
# 토론
#
# 별 표현식(*)을 이용한 언패킹 방식은 길이를 알 수 없는 순환체에 적용 가능하다.

# %%
# 별표 구문은 길이가 일정하지 않은 튜플에 사용하면 상당히 편리하다. 

records = [('foo', 1, 2),
          ('bar', 'hello'),
          ('foo', 3, 4),]

def do_foo(x, y):
    print('foo', x, y)

def do_bar(s):
    print('bar', s)

for tag, *args in records:
    if tag == 'foo':
        do_foo(*args)
    elif tag == 'bar':
        do_bar(*args)
# Out:
# foo 1 2
# bar hello
# foo 3 4

# %%
#문자열 프로세싱
line = 'nobody:*:-2:-2:Unprivileged User:/var/empty:/usr/bin/false'
uname, *fields, homedir, sh = line.split(':')
print(uname)
print(fields)
print(homedir)
print(sh)
# Out:
# nobody
# ['*', '-2', '-2', 'Unprivileged User']
# /var/empty
# /usr/bin/false

# %%
#언패킹 이후 특정 값을 버리고 싶으면 버리기용 변수_를 사용한다. 
record = ('ACME', 50, 123.45, (12, 18, 2012))
name, *_, (*_, year) = record
print(name)
print(year)
# Out:
# ACME
# 2012

# %%
#재귀 알고리즘을 사용하는 함수를 작성
items = [1,10,7,4,5,9]
head, *tail = items
print(head)
print(tail)
# Out:
# 1
# [10, 7, 4, 5, 9]

# %%
def sum(items):
    head, *tail = items
    return head + sum(tail) if tail else head

# %%
sum(items)
# Out:
# 36

# %% [markdown]
# ## 1.3 마지막 N개 아이템 유지
#
# 문제: 순환이나 프로세싱 중 마지막으로 발견한 N개의 아이템을 유지하고 싶다.

# %%
from collections import deque
def search(lines, pattern, history=5):
    previous_line = deque(maxlen=history)
    for line in lines:
        if pattern in line:
            yield line, previous_lines
        previous_line.append(line)

# %% [markdown]
# ## 1.4 N아이템의 최대 혹은 최소값 찾기
#
# 문제: 컬렉션 내부에서 가장 크거나 작은 N개의 아이템을 찾아야 한다.

# %%
import heapq
nums = [1, 8, 2, 23, 7, -4, 18, 23, 42, 37, 2]
print(heapq.nlargest(3, nums))
print(heapq.nsmallest(3, nums))
# Out:
# [42, 37, 23]
# [-4, 1, 2]

# %%
portfolio = [
    {'name':'IBM', 'shares':100, 'price':91.1,},
    {'name':'AAPL', 'shares':50, 'price':543.22,},
    {'name':'FB', 'shares':200, 'price':21.09,},
    {'name':'HQP', 'shares':35, 'price':31.75,},
    {'name':'YHOO', 'shares':45, 'price':16.35,},
    {'name':'ACME', 'shares':75, 'price':115.65,},
]
cheap = heapq.nsmallest(3, portfolio, key=lambda s: s['price'])
expensive = heapq.nlargest(3, portfolio, key=lambda s: s['price'])
cheap
# Out:
# [{'name': 'YHOO', 'shares': 45, 'price': 16.35},
#  {'name': 'FB', 'shares': 200, 'price': 21.09},
#  {'name': 'HQP', 'shares': 35, 'price': 31.75}]

# %%
expensive
# Out:
# [{'name': 'AAPL', 'shares': 50, 'price': 543.22},
#  {'name': 'ACME', 'shares': 75, 'price': 115.65},
#  {'name': 'IBM', 'shares': 100, 'price': 91.1}]

# %% [markdown]
# 토론
#
# 가장 작거나 큰 N개의 아이템을 찾고 있고 N이 컬렉션 전체 크기보다 작다면 앞에 나온 함수가 더 나은 성능을 제공한다.

# %% [markdown]
# ## 1.5 우선순위 큐 구현
#
# 문제: 주어진 순서에 따라 아이템을 정렬하는 큐를 구현하고 항상 우선순위가 높은 아이템을 먼저 팝하도록 만들어야 한다.

# %%
import heapq

class PriorityQueue:
    def __init__(self):
        self._queue = []
        self._index = 0
    def push(self, item, priority):
        heapq.heappush(self._queue, (-priority, self._index, item))
        self._index += 1
    def pop(self):
        return heapq.heappop(self._queue)[-1]

# %%
class Item:
    def __init__(self, name):
        self.name = name
    def __repr__(self):
        return 'Item({!r})'.format(self.name)

# %%
q = PriorityQueue()
q.push(Item('foo'), 1)
q.push(Item('bar'), 5)
q.push(Item('spam'), 4)
q.push(Item('grok'), 1)
q.pop()
# Out:
# Item('bar')

# %%
q.pop()
# Out:
# Item('spam')

# %%
q.pop()
# Out:
# Item('foo')

# %%
q.pop()
# Out:
# Item('grok')

# %% [markdown]
# 토론
#
# 여기서 중요한 점은 heaqp모듈의 사용법이다. heaqp.heappush()와 heaqp.heappop()은 list_queue의 첫 번째 아이템이 가장 작은 우선 순위를 가진 것처럼 아이템을 삽입하거나 제거한다.
#
# heappop()메소드는 항상 가장 작은 아이템을 반환해서 큐의 팝이 올바른 아이템에 적용될 수 있도록 한다. 그리고 힙의 크기가 N일때 푸시와 팝의 시간복잡도가 O(logN)이므로 N이 아주 커진다 해도 상당히 효율 적이다.

# %% [markdown]
# ## 1.6 딕셔너리의 키를 여러 값에 매핑하기
#
# 문제: 딕셔너리의 키를 하나 이상의 값에 매핑하고 싶다. (multidict)

# %% [markdown]
# 하나의 키에 하나의 값이 매핑되어 있는 것을 딕셔너리라 부른다. 키에 여러 값을 매핑하려면 그여러 값을 리스트나 세트같은 컨테이너에 따로 저장해 두어야 한다.

# %%
d = {'a' : [1, 2, 3],
     'b' : [4, 5]}
e = {'a' : {1, 2, 3},
     'b' : {4, 5}}

# %% [markdown]
# 쉽게 만드는 방법은 collections 모둘의 defaultdict를 사용한다.

# %%
from collections import defaultdict
d = defaultdict(list)
d['a'].append(1)
d['a'].append(2)
d['b'].append(4)
d
# Out:
# defaultdict(list, {'a': [1, 2], 'b': [4]})

# %%
d = defaultdict(set)
d['a'].add(1)
d['a'].add(2)
d['b'].add(4)
d
# Out:
# defaultdict(set, {'a': {1, 2}, 'b': {4}})

# %% [markdown]
# 토론
#
# 이론적으로 여러 값을 가지는 딕셔너리는 복잡하지는 않다

# %%
d = {}
pairs = [('a',80), ('b',65), ('c',30), ('a',99)]
for k, v in pairs:
    if k not in d:
        d[k] = []
    d[k].append(v)
d
# Out:
# {'a': [80, 99], 'b': [65], 'c': [30]}

# %% [markdown]
# defalutdict을 사용하면 더 깔끔한 코드가 된다.

# %%
from collections import defaultdict
d = defaultdict(set) #list
for k, v in pairs:
    d[k].add(v) #.append
d
# Out:
# defaultdict(set, {'a': {80, 99}, 'b': {65}, 'c': {30}})

# %% [markdown]
# ## 1.7 딕셔너리 순서 유지
#
# 문제: 딕셔너리를 만들고, 순환이나 직렬화할 때 순서를 조절하고 싶다.

# %%
from collections import OrderedDict
d = OrderedDict()
d['foo'] = 1
d['bar'] = 2
d['spam'] = 3
d['grok'] = 4
d
# Out:
# OrderedDict([('foo', 1), ('bar', 2), ('spam', 3), ('grok', 4)])

# %%
for key in d:
    print(key, d[key])
# Out:
# foo 1
# bar 2
# spam 3
# grok 4

# %% [markdown]
# OrderedDict은 나중에 직렬화하거나 다른 포맷으로 인코딩할 때 다른 매핑을 만들 때 특히 유용하다. 예를 들어, JSON인코딩에 나타나는 특정 필드의 순서를 조절하기 위해서 OrderedDict에 다음과 같이 데이터를 생성한다.

# %%
import json
json.dumps(d)
# Out:
# '{"foo": 1, "bar": 2, "spam": 3, "grok": 4}'

# %% [markdown]
# ## 1.8 딕셔너리 계산
#
# 문제: 딕셔너리 데이터에 여러 계산을 수행하고 싶다(최소값, 최대값, 정렬 등)

# %%
prices = {'ACME': 45.23, 
          'AAPL': 612.78,
          'IBM': 205.55,
          'HPQ': 37.20,
          'FB': 10.75}

# %%
min_price = min(zip(prices.values(), prices.keys()))
min_price
# Out:
# (10.75, 'FB')

# %%
min_price = min(zip(prices.keys(), prices.values()))
min_price
# Out:
# ('AAPL', 612.78)

# %%
min_price = min(zip(prices.items()))
min_price
# Out:
# (('AAPL', 612.78),)

# %%
max_price = max(zip(prices.values(), prices.keys()))
max_price
# Out:
# (612.78, 'AAPL')

# %%
prices_sorted = sorted(zip(prices.values(), prices.keys()))
prices_sorted
# Out:
# [(10.75, 'FB'),
#  (37.2, 'HPQ'),
#  (45.23, 'ACME'),
#  (205.55, 'IBM'),
#  (612.78, 'AAPL')]

# %% [markdown]
# zip()은 단 한번만 소비할 수 있는 이터레이터를 생성한다. 따라서 꼭 리스트나 튜플로 변환해 주어야 한다.!
# min(), max() sorted()함수는 각각 tuple이나 list로 반환해준다.

# %% [markdown]
# 토론
#
# min()함수의 key를 이용한다.

# %%
min(prices, key=lambda k: prices[k])
# Out:
# 'FB'

# %%
max(prices, key=lambda k: prices[k])
# Out:
# 'AAPL'

# %% [markdown]
# ## 1.9 두 딕셔너리의 유사점 찾기
#
# 문제: 두 딕셔너리가 있고 여기서 유사점을 찾고 싶다. (동일한 키, 동일한 값 등)

# %%
a = {'x': 1,
     'y': 2,
     'z': 3}

b = {'w': 10,
     'x': 11,
     'y': 2}

# %%
# 동일한 키 찾기
a.keys() & b.keys()
# Out:
# {'x', 'y'}

# %%
# a에만 있고 b에는 없는 키 찾기
a.keys() - b.keys()
# Out:
# {'z'}

# %%
# 키, 값이 동일한 것 찾기
a.items() & b.items()
# Out:
# {('y', 2)}

# %%
# 특정한 키를 제거한 새로운 딕셔너리 만들기
c = {key:a[key] for key in a.keys() - {'z', 'w'}}
c
# Out:
# {'x': 1, 'y': 2}

# %% [markdown]
# 토론
#
# 딕셔너리는 키와 값의 매핑으로 이루어진다. 딕셔너리의 keys()메소드는 키를 노출하는 키-뷰(key-view)객체를 반환한다. 키 뷰에는 잘 알려지지 않았지만 합집합, 교집합, 여집합과 같은 집합 연산 기능이 있다. 따라서 딕셔너리 키에 집합 연산을 수행하려면 집합으로 변환할 필요 없이 키-뷰 객체를 바로 사용하면 된다.
#
# 딕셔너리의 items()메소드는 key, values페어로 구성된 아이템-뷰 객체를 반환한다. 이 객체는 집합연산과 유사한 것을 지원하므로 두 딕셔너리에 동일한 키-값 페어를 찾을 때 사용할 수 있다.
#
# 유사하긴 하지만 values()메소드는 앞에 나온 집합 연산을 지원하지 않는다. 이는 키와는 다르게 값-뷰는 유일하다는 보장이 없기 때문이다. 그래서 값은 집합으로 변환한뒤 집합연산을 사용하면 된다.

# %% [markdown]
# ## 1.10 순서를 깨지 않고 시퀀스의 중복 없애기
#
# 문제: 시퀀스에서 중복된 값을 없애고 싶지만, 아이템의 순서는 유지하고 싶다.

# %% [markdown]
# 시퀀스의 값이 해시 가능하다면 이 문제는 세트와 제너레이터를 사용해서 쉽게 해결할 수 있다.

# %%
def dedupe(items):
    seen = set()
    for item in items:
        if item not in seen:
            yield item
            seen.add(item)

# %%
a = [1, 5, 2, 1, 9, 1, 5, 10]
list(dedupe(a))
# Out:
# [1, 5, 2, 9, 10]

# %% [markdown]
# 앞에서도 말했지만 시퀀스의 아이템이 해시 가능한 경우에만 사용할 수 있다. 해시 불가능한 타입(dict)의 중복을 없애려면 아래와 같이 수정한다.

# %%
def dedupe(items, key=None):
    seen = set()
    for item in items:
        val = item if key is None else key(item)
        if val not in seen:
            yield item
            seen.add(val)

# %%
a = [{'x':1, 'y':2}, {'x':1, 'y':3}, {'x':1, 'y':2}, {'x':2, 'y':4}]
list(dedupe(a, key=lambda d: (d['x'],d['y'])))
# Out:
# [{'x': 1, 'y': 2}, {'x': 1, 'y': 3}, {'x': 2, 'y': 4}]

# %%
list(dedupe(a, key=lambda d: d['x']))
# Out:
# [{'x': 1, 'y': 2}, {'x': 2, 'y': 4}]

# %% [markdown]
# 토론
#
# 중복을 없애려면 대개 세트를 만드는 것이 가장 쉽다.
# 그러나 순서가 훼손된다.

# %% [markdown]
# ## 1.12 시퀀스에 가장 많은 아이템 찾기
#
# 문제: 시퀀스에 가장 많이 나타난 아이템을 찾고 싶다.

# %% [markdown]
# collections.Counter를 이용한다. most_common()메소드를 이용하면 좋다.

# %%
words = [
    'look', 'into', 'my', 'eyes', 'look', 'into', 'my', 'eyes', 'the', 'eyes', 'the', 'eyes', 
    'the', 'eyes', 'not', 'around', 'the', 'eyes', "don't", 'look', 'around', 'the', 'eyes',
    'look', 'into', 'my', 'eyes', "you're", 'under'
]

# %%
from collections import Counter
word_counts = Counter(words)
top_three = word_counts.most_common(3)
top_three
# Out:
# [('eyes', 8), ('the', 5), ('look', 4)]

# %% [markdown]
# 토론
#
# Counter 객체에는 해시 가능한 모든 아이템을 입력할 수 있다. 내부적으로 Counter는 아이템이 나타난 횟수를 가리키는 딕셔너리이다.

# %%
word_counts['not']
# Out:
# 1

# %%
word_counts['eyes']
# Out:
# 8

# %% [markdown]
# 카운트를 수동으로 증가시키고 싶다면 단순하게 더하기를 사용한다.

# %%
morewords = ['why', 'are', 'you', 'not', 'looking', 'in', 'my', 'eyes']
for word in morewords:
    word_counts[word] += 1
word_counts['eyes']
# Out:
# 10

# %%
word_counts.update(morewords)

# %% [markdown]
# ## 1.13 일반키로 딕셔너리 리스트 정렬
#
# 문제: 딕셔너리 리스트가 있고, 하나 혹은 그 이상의 딕셔너리 값으로 이를 정렬하고 싶다.

# %% [markdown]
# 이와 같은 구조는 operator 모듈의 itemgetter함수를 사용하면 쉽게 정렬할 수 있다. 어느 웹 사이트 회원 리스트를 데이터베이스로부터 불러와 다음과 같은 자료 구조를 만들었다고 가정해보자

# %%
rows = [
    {'fname': 'Braian', 'lname':'Jones','uid':1003},
    {'fname': 'David', 'lname':'Beazley','uid':1002},
    {'fname': 'John', 'lname':'Cleese','uid':1001},
    {'fname': 'Big', 'lname':'Jones','uid':1004},
]

# %% [markdown]
# 모든 딕셔너리에 포함된 필드를 기준으로 데이터를 정렬해 출력하는 것은 어렵지 않다.

# %%
from operator import itemgetter
rows_by_fname = sorted(rows, key=itemgetter('fname'))
rows_by_uid = sorted(rows, key=itemgetter('uid'))
rows_by_fname
# Out:
# [{'fname': 'Big', 'lname': 'Jones', 'uid': 1004},
#  {'fname': 'Braian', 'lname': 'Jones', 'uid': 1003},
#  {'fname': 'David', 'lname': 'Beazley', 'uid': 1002},
#  {'fname': 'John', 'lname': 'Cleese', 'uid': 1001}]

# %%
rows_by_uid
# Out:
# [{'fname': 'John', 'lname': 'Cleese', 'uid': 1001},
#  {'fname': 'David', 'lname': 'Beazley', 'uid': 1002},
#  {'fname': 'Braian', 'lname': 'Jones', 'uid': 1003},
#  {'fname': 'Big', 'lname': 'Jones', 'uid': 1004}]

# %%
#itemgetter()함수에는 키를 여러개 전달할 수도 있다. 
rows_by_lname = sorted(rows, key=itemgetter('lname', 'fname'))
rows_by_lname
# Out:
# [{'fname': 'David', 'lname': 'Beazley', 'uid': 1002},
#  {'fname': 'John', 'lname': 'Cleese', 'uid': 1001},
#  {'fname': 'Big', 'lname': 'Jones', 'uid': 1004},
#  {'fname': 'Braian', 'lname': 'Jones', 'uid': 1003}]

# %% [markdown]
# 토론
#
# 이번 예제에서 키워드 인자 key를 받는 내장함수 sorted()에 rows를 전달했다. 이 인자는 rows로부터 단일 아이템을 받는 호출 가능 객체를 입력으로 받고 정렬의 기본이 되는 값을 반환 한다. itemgetter()함수는 그런 호출가능 객체를 생성한다.
#
# operator.itemgetter()함수는 rows레코드에서 원하는 값을 추출하는데 사용하는 인덱스를 인자로 받는다. 딕셔너리 키 이름이나 숫자 리스트 요소가 될 수도 있고, 객체의 ```__getitem__()```메소드에 넣을 수 있는 모든 값이 가능하다.
#
# itemgetter()에 여러 인덱스를 전달하면, 생성한 호출 가능 객체가 모든 요소를 가지고 있는 튜플을 반환하고, sorted()가 튜플의 정렬 순서에 따라 결과의 순서를 잡는다.
#
# 이 방식은 여러 필드를 동시에 정렬할 때 유용하다.

# %%
#itemgetter()의 기능을 lambda 표현식으로 대체할 수 있다.
rows_by_fname = sorted(rows, key=lambda r:r['fname'])
rows_by_lname = sorted(rows, key=lambda r:(r['lname'], r['fname']))

# %% [markdown]
# 이 코드도 잘 동작하지만 itemgetter()를 사용한 코드의 실행 속도가 조금 더 빠르다.

# %%
min(rows, key=itemgetter('uid'))
# Out:
# {'fname': 'John', 'lname': 'Cleese', 'uid': 1001}

# %%
max(rows, key=itemgetter('uid'))
# Out:
# {'fname': 'Big', 'lname': 'Jones', 'uid': 1004}

# %% [markdown]
# ## 1.14 기본 비교 기능 없이 객체 정렬
#
# 문제: 동일한 클래스 객체를 정렬해야 하는데, 이 클래스는 기본적인 비교 연산을 제공하지 않는다.

# %% [markdown]
# 내장 함수 sorted()는 key인자에 호출 가능 객체를 받아 sorted가 객체 비교에 사용할 수 있는 값을 반환한다. 예를 들어, 애플리케이션에 User인스턴스를 시퀀스로 갖고 있고 이를 user_id요소를 기반으로 정렬하고 싶다. 이럴때는 User인스턴스를 입력으로 받고 user_id를 반환하는 코드를 작성할 수 있다.

# %%
class User:
    def __init__(self, user_id):
        self.user_id = user_id
    def __repr__(self):
        return 'User({})'.format(self.user_id)

# %%
users = [User(23), User(3), User(90)]
users
# Out:
# [User(23), User(3), User(90)]

# %%
from operator import attrgetter
sorted(users, key=attrgetter('user_id'))
# Out:
# [User(3), User(23), User(90)]

# %%
min(users, key=attrgetter('user_id'))
# Out:
# User(3)

# %%
max(users, key=attrgetter('user_id'))
# Out:
# User(90)

# %% [markdown]
# ## 1.15 필드에 따라 레코드 묶기
#
# 문제: 일련의 딕셔너리나 인스턴스가 있고 특정 필드 값에 기반한 그룹의 데이터를 순환하고 싶다.

# %% [markdown]
# 해결: itertools.groupby()함수는 이와 같은 데이터를 묶는데 유용하다. 다음과 같은 딕셔너리 리스트가 있다고 가정해 보자.

# %%
rows = [
    {'address': '5412 N CLARK', 'date':'07/01/2012'},
    {'address': '5148 N CLARK', 'date':'07/04/2012'},
    {'address': '5800 N 58TH', 'date':'07/02/2012'},
    {'address': '2122 N CLARK', 'date':'07/03/2012'},
    {'address': '5645 N RAVENSWOOD', 'date':'07/02/2012'},
    {'address': '1060 W ADDISON', 'date':'07/02/2012'},
    {'address': '4801 N BROADWAY', 'date':'07/01/2012'},
    {'address': '1039 W GRANVILLE', 'date':'07/04/2012'},
]

# %%
from operator import itemgetter
from itertools import groupby

rows.sort(key=itemgetter('date'))
for date, items in groupby(rows, key=itemgetter('date')):
    print(date)
    for i in items:
        print('  ', i)
# Out:
# 07/01/2012
#    {'address': '5412 N CLARK', 'date': '07/01/2012'}
#    {'address': '4801 N BROADWAY', 'date': '07/01/2012'}
# 07/02/2012
#    {'address': '5800 N 58TH', 'date': '07/02/2012'}
#    {'address': '5645 N RAVENSWOOD', 'date': '07/02/2012'}
#    {'address': '1060 W ADDISON', 'date': '07/02/2012'}
# 07/03/2012
#    {'address': '2122 N CLARK', 'date': '07/03/2012'}
# 07/04/2012
#    {'address': '5148 N CLARK', 'date': '07/04/2012'}
#    {'address': '1039 W GRANVILLE', 'date': '07/04/2012'}

# %% [markdown]
# 토론
#
# groupby() 함수는 시퀀스를 검색하고 동일한 값(키 함수에서 반환한 값)에 대한 일련의 "실행"을 찾는다. 개별 순환에 대해서 값, 그리고 같은 값을 가진 그룹의 모든 아이템을 만드는 이터레이터(iterator)를 함께 반환한다.
#
# 그에 앞서 원하는 필드에 따라 데이터를 정렬해야 하는 과정이 중요하다. groupby()함수는 연속된 아이템에만 동작하기 때문에 정렬 과정을 생략하면 원하는 대로 함수를 실행할 수 없다.
#
# 단순히 날짜에 따라 데이터를 묶어서 커더란 자료 구조에 넣어 놓고 원할 때마다 접근하려는 것이라면, 레시피 1.6에 나온 대로 defalutdict()를 사용해서 multidict를 구성하는게 나을 수도 있다.

# %%
from collections import defaultdict
rows_by_date = defaultdict(list)
for row in rows:
    rows_by_date[row['date']].append(row)

# %%
for r in rows_by_date['07/01/2012']:
    print(r)
# Out:
# {'address': '5412 N CLARK', 'date': '07/01/2012'}
# {'address': '4801 N BROADWAY', 'date': '07/01/2012'}

# %% [markdown]
# ## 1.16 시퀀스 필터링
#
# 문제: 시퀀스 내부에 데이터가 있고 특정 조건에 따라 값을 추출하거나 줄이고 싶다.

# %%
mylist = [1, 4, -5, 10, -7, 2, 3, -1]
[n for n in mylist if n >0]
# Out:
# [1, 4, 10, 2, 3]

# %% [markdown]
# 리스트 컴프리헨션을 이용한다.!

# %%
values = ['1', '2', '-3', '4', 'N/A', '5']
def is_int(val):
    try:
        x = int(val)
        return True
    except ValueError:
        return False

# %%
ivals = list(filter(is_int, values))
print(ivals)
# Out:
# ['1', '2', '-3', '4', '5']

# %% [markdown]
# filter()는 이터레이터를 생성한다. 따라서 결과의 리스트를 만들고 싶다면 list()함수를 사용해야 한다.

# %% [markdown]
# 토론
#
# itertools.compress()를 사용한다.

# %%
address = ['5412 N CLARK', '5418 N CLARK', '5800 E 58TH', '2122 N CLARK', '5645 N RAVENSWOOD',
           '1060 W ADDISON', '4801 N BROADWAY', '1039 W GRANVILLE']

# %%
#count값이 5이상인 주소만 남기려고 한다. 
counts = [0, 3, 10, 4, 1, 7, 6, 1]

# %%
from itertools import compress
more5 = [n > 5 for n in counts]
more5
# Out:
# [False, False, True, False, False, True, True, False]

# %%
list(compress(address, more5))
# Out:
# ['5800 E 58TH', '1060 W ADDISON', '4801 N BROADWAY']

# %% [markdown]
# Boolean 셀렉터 시퀀스를 입력으로 받는다. 이렇게 하면 셀렉터에서 조건이 참인 요소만 골라서 반환할 수 있다.
#
# 주어진 조건에 만족하는지 여부를 담은 Boolean 시퀀스를 만들어 두고 compress()함수로 True에 일치하는 값만 골라낸다.
# compress()역시 이터레이터를 반환한다. 따라서 list()를 사용해야 한다.

# %% [markdown]
# ## 1.17 딕셔너리의 부분 추출
#
# 문제: 딕셔너리의 특정 부분으로부터 다른 딕셔너리를 만들고 싶다.

# %%
prices = {
    'ACME': 45.23,
    'AAPL': 612.78,
    'IBM':205.55,
    'HPQ':37.20,
    'FB':10.75
}

# %%
p1 = {key:value for key, value in prices.items() if value > 200}
p1
# Out:
# {'AAPL': 612.78, 'IBM': 205.55}

# %%
tech_names = {'AAPL', 'FB'}
p2 = {k:v for k, v in prices.items() if k in tech_names}
p2
# Out:
# {'AAPL': 612.78, 'FB': 10.75}

# %% [markdown]
# ## 1.18 시퀀스 요소에 이름 매핑
#
# 문제: 리스트나 튜플의 위치로 요소에 접근하는 코드가 있다. 하지만 코드의 가독성이 떨어진다. 위치에 의존하는 코드의 구조도 이름으로 접근 가능하도록 수정하고 싶다.

# %% [markdown]
# namedtuple을 이용한다!

# %%
from collections import namedtuple

Subscriber = namedtuple('Subscriber', ['addr', 'joined'])
sub = Subscriber('jonesy@example.com', '2012-10-19')
sub
# Out:
# Subscriber(addr='jonesy@example.com', joined='2012-10-19')

# %%
sub.addr
# Out:
# 'jonesy@example.com'

# %% [markdown]
# namedtuple은 클래스 인스턴스와 비슷해 보이지만 튜플과 교환이 가능하고 인덱싱이나 언패킹 같은 튜플의 일반적인 기능을 모두 지원한다.

# %%
len(sub)
# Out:
# 2

# %%
ddr, joined = sub
joined
# Out:
# '2012-10-19'

# %% [markdown]
# 네임드튜플은 주로 요소의 위치를 기반으로 구현되어 있는 코드를 분리한다. 따라서 데이터베이스로부터 거대한 튜플 리스트를 받고 요소의 위치로 접근하는 코드가 있을 때, 예를 들어 테이블에 새로운 열이 추가되었다거나 할 때 문제가 생길 수 있다. 하지만 반환된 튜플을 네임드 튜플로 반환했다면 이런 문제를 예방할 수 있다.

# %%
def compute_cost(records):
    total = 0.0
    for rec in records:
        total += rec[1] * rec[2]
    return total

# %% [markdown]
# ## 1.20 여러 매핑을 단일 매핑으로 합치기
#
# 문제: 딕셔너리나 매핑이 여러 개 있고, 자료 검색이나 데이터 확인을 위해서 하나의 매핑으로 합치고 싶다.

# %%
a = {'x':1, 'z': 3}
b = {'y':2, 'z': 4}

# %% [markdown]
# 이제 두 딕셔너리에서 모두 검색해야 하는 상황이라고 가정하자.

# %%
from collections import ChainMap
c = ChainMap(a, b)
c['x']
# Out:
# 1

# %%
c['z']
# Out:
# 3

# %%
merged = dict(b)
merged.update(a)

# %%
merged['y']
# Out:
# 2

# %% [markdown]
# chainmap은 매핑을 여러개 받아서 하나처럼 보이게 만든다. 단, 합치는 것은 아니다.
#
# 새로운 dict()을 만들고 update를 해도 된다.
