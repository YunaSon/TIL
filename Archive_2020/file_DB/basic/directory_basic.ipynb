# %% [markdown]
# ## 자주 나오는 명령어
#
# - os.listdir()
# - glob.glob()
# - os.path.join()
# - os.path.exists()
# - glob.glob(os.path.join())
# - ```sys.argv[1]```
# - os.getcwd()

# %%
import os, sys, glob

# %%
photodir = '/Users/jooyoungson/Documents/photo'

# %%
len(os.listdir(photodir))
# Out:
# 95

# %%
glob.glob(photodir)
# Out:
# ['/Users/jooyoungson/Documents/photo']

# %%
len(glob.glob(os.path.join(photodir, '*.jpg')))
# Out:
# 44

# %%
os.path.exists(photodir)
# Out:
# True

# %%
os.getcwd()
# Out:
# '/Users/jooyoungson/TIL/file/basic'
