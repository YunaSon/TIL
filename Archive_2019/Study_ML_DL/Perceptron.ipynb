# %%
import torch

# %% [markdown]
# ### <font color=orange>XOR Gate

# %%
X = torch.

# %% [markdown]
# ### <font color=orange> Multi Layer Perceptron (MLP)

# %% [markdown]
# - Backpropagation을 통해 Multi Layer Perceptron을 학습한다.

# %%
X = torch.FloatTensor([])
