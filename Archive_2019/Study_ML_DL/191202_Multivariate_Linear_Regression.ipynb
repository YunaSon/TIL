# %% [markdown]
# ## Multivariate Linear Regression

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
from torch.utils.data import Dataset, DataLoader

class CustomDataset(Dataset):
    def __init__(self):
        self.x_data = [[73, 80, 75],
                      [93, 88, 93],
                      [89, 91, 90],
                      [96, 98, 100],
                      [73, 66, 70]]
        self.y_data = [[152],[185],[180],[196],[142]]
        
    def __len__(self):
        return len(self.x_data)
    
    def __getitem__(self, idx):
        x = torch.FloatTensor(self.x_data[idx])
        y = torch.FloatTensor(self.y_data[idx])
        
        return x, y

# %%
dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size = 2, shuffle = True)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
    for batch_idx, samples in enumerate(dataloader):
        x_train, y_train = samples
        # H(x)계산
        prediction = model(x_train)
        
        # cost계산
        cost = F.mse_loss(prediction, y_train)
        
        # cost로 H(x)계산
        optimizer.zero_grad()
        cost.backward()
        optimizer.step()
    print("Epoch {:4d}/{} Batch {}/{} Cost:{:.6f}".format(epoch, nb_epochs, batch_idx+1, len(dataloader), cost.item()))

# %%
# getitem에서는 인덱스 하나를 받아서 그에 맞는 입력과 출력 데이터를 찾은 후 이 입출력 데이터를 torch.tensor형태로 반환
# dataloader를 이용가능

# %%
# enumerate(dataloader)
# - minibatch인덱스와 데이터를 받음.

# %%
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

# %%
W = torch.zeros(1, requires_grad = True)
b = torch.zeros(1, requires_grad = True)
hypothesis = x_train*W + b
cost = torch.mean((hypothesis - y_train)**2)

# %%
optimizer = optim.SGD([W, b], lr= 0.01)

optimizer.zero_grad()
cost.backward()
optimizer.step()

# %%
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

W = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

optimizer = optim.SGD([W, b], lr = 0.01)

nb_epochs = 100
for epoch in range(1, nb_epochs + 1):
    #가설함수
    hypothesis = x_train*W + b
    
    #cost함수
    cost = torch.mean((hypothesis - y_train)**2)
    
    #W, b를 학습
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    print(W, b)
    #print(hypothesis)
    print(cost.item())
# Out:
# tensor([0.1867], requires_grad=True) tensor([0.0800], requires_grad=True)
# 18.66666603088379
# tensor([0.3527], requires_grad=True) tensor([0.1509], requires_grad=True)
# 14.770962715148926
# tensor([0.5004], requires_grad=True) tensor([0.2138], requires_grad=True)
# 11.691540718078613
# tensor([0.6318], requires_grad=True) tensor([0.2695], requires_grad=True)
# 9.257344245910645
# tensor([0.7487], requires_grad=True) tensor([0.3188], requires_grad=True)
# 7.333169460296631
# tensor([0.8528], requires_grad=True) tensor([0.3625], requires_grad=True)
# 5.812135219573975
# tensor([0.9453], requires_grad=True) tensor([0.4012], requires_grad=True)
# 4.6097636222839355
# tensor([1.0277], requires_grad=True) tensor([0.4353], requires_grad=True)
# 3.65927791595459
# tensor([1.1011], requires_grad=True) tensor([0.4655], requires_grad=True)
# 2.907895803451538
# tensor([1.1663], requires_grad=True) tensor([0.4922], requires_grad=True)
# 2.313894510269165
# tensor([1.2245], requires_grad=True) tensor([0.5157], requires_grad=True)
# 1.8442937135696411
# tensor([1.2762], requires_grad=True) tensor([0.5364], requires_grad=True)
# 1.4730267524719238
# tensor([1.3223], requires_grad=True) tensor([0.5546], requires_grad=True)
# 1.179486870765686
# tensor([1.3634], requires_grad=True) tensor([0.5706], requires_grad=True)
# 0.9473860859870911
# tensor([1.4000], requires_grad=True) tensor([0.5847], requires_grad=True)
# 0.7638508677482605
# tensor([1.4326], requires_grad=True) tensor([0.5970], requires_grad=True)
# 0.6187044978141785
# tensor([1.4617], requires_grad=True) tensor([0.6077], requires_grad=True)
# 0.5039023756980896
# tensor([1.4876], requires_grad=True) tensor([0.6171], requires_grad=True)
# 0.41308578848838806
# tensor([1.5107], requires_grad=True) tensor([0.6253], requires_grad=True)
# 0.341229110956192
# tensor([1.5314], requires_grad=True) tensor([0.6323], requires_grad=True)
# 0.2843596935272217
# tensor([1.5498], requires_grad=True) tensor([0.6384], requires_grad=True)
# 0.23933714628219604
# tensor([1.5663], requires_grad=True) tensor([0.6437], requires_grad=True)
# 0.2036794275045395
# tensor([1.5811], requires_grad=True) tensor([0.6481], requires_grad=True)
# 0.17542403936386108
# tensor([1.5942], requires_grad=True) tensor([0.6519], requires_grad=True)
# 0.15302066504955292
# tensor([1.6060], requires_grad=True) tensor([0.6551], requires_grad=True)
# 0.1352430135011673
# tensor([1.6166], requires_grad=True) tensor([0.6578], requires_grad=True)
# 0.12112198024988174
# tensor([1.6261], requires_grad=True) tensor([0.6600], requires_grad=True)
# 0.10989169031381607
# tensor([1.6346], requires_grad=True) tensor([0.6617], requires_grad=True)
# 0.10094710439443588
# tensor([1.6422], requires_grad=True) tensor([0.6631], requires_grad=True)
# 0.09380906820297241
# tensor([1.6491], requires_grad=True) tensor([0.6641], requires_grad=True)
# 0.08809951692819595
# tensor([1.6553], requires_grad=True) tensor([0.6649], requires_grad=True)
# 0.08351940661668777
# tensor([1.6608], requires_grad=True) tensor([0.6654], requires_grad=True)
# 0.07983262091875076
# tensor([1.6659], requires_grad=True) tensor([0.6656], requires_grad=True)
# 0.07685187458992004
# tensor([1.6704], requires_grad=True) tensor([0.6657], requires_grad=True)
# 0.07442975789308548
# tensor([1.6746], requires_grad=True) tensor([0.6656], requires_grad=True)
# 0.07244965434074402
# tensor([1.6783], requires_grad=True) tensor([0.6653], requires_grad=True)
# 0.07081900537014008
# tensor([1.6817], requires_grad=True) tensor([0.6648], requires_grad=True)
# 0.06946494430303574
# tensor([1.6848], requires_grad=True) tensor([0.6643], requires_grad=True)
# 0.06832986325025558
# tensor([1.6877], requires_grad=True) tensor([0.6636], requires_grad=True)
# 0.06736820936203003
# tensor([1.6903], requires_grad=True) tensor([0.6628], requires_grad=True)
# 0.06654402613639832
# tensor([1.6927], requires_grad=True) tensor([0.6619], requires_grad=True)
# 0.06582852452993393
# tensor([1.6949], requires_grad=True) tensor([0.6610], requires_grad=True)
# 0.06519965082406998
# tensor([1.6969], requires_grad=True) tensor([0.6600], requires_grad=True)
# 0.06463920325040817
# tensor([1.6988], requires_grad=True) tensor([0.6589], requires_grad=True)
# 0.06413326412439346
# tensor([1.7006], requires_grad=True) tensor([0.6578], requires_grad=True)
# 0.06367083638906479
# tensor([1.7022], requires_grad=True) tensor([0.6566], requires_grad=True)
# 0.06324289739131927
# tensor([1.7037], requires_grad=True) tensor([0.6554], requires_grad=True)
# 0.06284261494874954
# tensor([1.7052], requires_grad=True) tensor([0.6541], requires_grad=True)
# 0.062464598566293716
# tensor([1.7065], requires_grad=True) tensor([0.6528], requires_grad=True)
# 0.06210431829094887
# tensor([1.7078], requires_grad=True) tensor([0.6515], requires_grad=True)
# 0.06175841763615608
# tensor([1.7090], requires_grad=True) tensor([0.6502], requires_grad=True)
# 0.06142409145832062
# tensor([1.7102], requires_grad=True) tensor([0.6488], requires_grad=True)
# 0.061099350452423096
# tensor([1.7113], requires_grad=True) tensor([0.6474], requires_grad=True)
# 0.060782402753829956
# tensor([1.7123], requires_grad=True) tensor([0.6460], requires_grad=True)
# 0.06047193706035614
# tensor([1.7133], requires_grad=True) tensor([0.6446], requires_grad=True)
# 0.06016680225729942
# tensor([1.7143], requires_grad=True) tensor([0.6432], requires_grad=True)
# 0.05986620858311653
# tensor([1.7152], requires_grad=True) tensor([0.6417], requires_grad=True)
# 0.059569526463747025
# tensor([1.7161], requires_grad=True) tensor([0.6403], requires_grad=True)
# 0.059276282787323
# tensor([1.7170], requires_grad=True) tensor([0.6389], requires_grad=True)
# 0.058985840529203415
# tensor([1.7179], requires_grad=True) tensor([0.6374], requires_grad=True)
# 0.058698009699583054
# tensor([1.7187], requires_grad=True) tensor([0.6359], requires_grad=True)
# 0.05841260030865669
# tensor([1.7195], requires_grad=True) tensor([0.6345], requires_grad=True)
# 0.05812925100326538
# tensor([1.7203], requires_grad=True) tensor([0.6330], requires_grad=True)
# 0.05784786865115166
# tensor([1.7211], requires_grad=True) tensor([0.6315], requires_grad=True)
# 0.05756834149360657
# tensor([1.7219], requires_grad=True) tensor([0.6300], requires_grad=True)
# 0.057290464639663696
# tensor([1.7226], requires_grad=True) tensor([0.6286], requires_grad=True)
# 0.057014238089323044
# tensor([1.7234], requires_grad=True) tensor([0.6271], requires_grad=True)
# 0.05673956498503685
# tensor([1.7241], requires_grad=True) tensor([0.6256], requires_grad=True)
# 0.05646643415093422
# tensor([1.7248], requires_grad=True) tensor([0.6241], requires_grad=True)
# 0.0561947263777256
# tensor([1.7256], requires_grad=True) tensor([0.6227], requires_grad=True)
# 0.0559244342148304
# tensor([1.7263], requires_grad=True) tensor([0.6212], requires_grad=True)
# 0.05565551295876503
# tensor([1.7270], requires_grad=True) tensor([0.6197], requires_grad=True)
# 0.055387943983078
# tensor([1.7277], requires_grad=True) tensor([0.6182], requires_grad=True)
# 0.0551217757165432
# tensor([1.7283], requires_grad=True) tensor([0.6168], requires_grad=True)
# 0.054856956005096436
# tensor([1.7290], requires_grad=True) tensor([0.6153], requires_grad=True)
# 0.05459338054060936
# tensor([1.7297], requires_grad=True) tensor([0.6138], requires_grad=True)
# 0.054331064224243164
# tensor([1.7304], requires_grad=True) tensor([0.6124], requires_grad=True)
# 0.0540701262652874
# tensor([1.7311], requires_grad=True) tensor([0.6109], requires_grad=True)
# 0.053810421377420425
# tensor([1.7317], requires_grad=True) tensor([0.6094], requires_grad=True)
# 0.05355193093419075
# tensor([1.7324], requires_grad=True) tensor([0.6080], requires_grad=True)
# 0.053294796496629715
# tensor([1.7330], requires_grad=True) tensor([0.6065], requires_grad=True)
# 0.05303886532783508
# tensor([1.7337], requires_grad=True) tensor([0.6051], requires_grad=True)
# 0.05278408154845238
# tensor([1.7343], requires_grad=True) tensor([0.6036], requires_grad=True)
# 0.052530597895383835
# tensor([1.7350], requires_grad=True) tensor([0.6022], requires_grad=True)
# 0.052278321236371994
# tensor([1.7356], requires_grad=True) tensor([0.6007], requires_grad=True)
# 0.05202724039554596
# tensor([1.7363], requires_grad=True) tensor([0.5993], requires_grad=True)
# 0.05177744850516319
# tensor([1.7369], requires_grad=True) tensor([0.5979], requires_grad=True)
# 0.05152879282832146
# tensor([1.7376], requires_grad=True) tensor([0.5964], requires_grad=True)
# 0.051281318068504333
# tensor([1.7382], requires_grad=True) tensor([0.5950], requires_grad=True)
# 0.05103505775332451
# tensor([1.7388], requires_grad=True) tensor([0.5936], requires_grad=True)
# 0.050789956003427505
# tensor([1.7395], requires_grad=True) tensor([0.5921], requires_grad=True)
# 0.05054604634642601
# tensor([1.7401], requires_grad=True) tensor([0.5907], requires_grad=True)
# 0.05030332878232002
# tensor([1.7407], requires_grad=True) tensor([0.5893], requires_grad=True)
# 0.05006173253059387
# tensor([1.7414], requires_grad=True) tensor([0.5879], requires_grad=True)
# 0.04982137680053711
# tensor([1.7420], requires_grad=True) tensor([0.5865], requires_grad=True)
# 0.049582112580537796
# tensor([1.7426], requires_grad=True) tensor([0.5851], requires_grad=True)
# 0.049344033002853394
# tensor([1.7432], requires_grad=True) tensor([0.5837], requires_grad=True)
# 0.049107104539871216
# tensor([1.7438], requires_grad=True) tensor([0.5823], requires_grad=True)
# 0.0488712340593338
# tensor([1.7445], requires_grad=True) tensor([0.5809], requires_grad=True)
# 0.048636626452207565
# tensor([1.7451], requires_grad=True) tensor([0.5795], requires_grad=True)
# 0.048402994871139526

# %%
#데이터
x_train = torch.FloatTensor([[1],[2],[3]])
y_train = torch.FloatTensor([[1],[2],[3]])
#모델 초기화
W = torch.zeros(1)
lr = 0.1

nb_epochs = 10
for epoch in range(nb_epochs + 1):
    
    # H(x) 계산
    hypothesis = x_train + W
    
    # cost gradient 계산
    cost = torch.mean((hypothesis - y_train)**2)
    gradient = torch.sum((W * x_train - y_train) * x_train)
    
    print("Epoch {:4d}/{} W: {:.3f}, Cost: {:.6f}".format(epoch, nb_epochs, W.item(), cost.item()))
    
    W -= lr*gradient
# Out:
# Epoch    0/10 W: 0.000, Cost: 0.000000
# Epoch    1/10 W: 1.400, Cost: 1.960000
# Epoch    2/10 W: 0.840, Cost: 0.705600
# Epoch    3/10 W: 1.064, Cost: 1.132096
# Epoch    4/10 W: 0.974, Cost: 0.949455
# Epoch    5/10 W: 1.010, Cost: 1.020585
# Epoch    6/10 W: 0.996, Cost: 0.991825
# Epoch    7/10 W: 1.002, Cost: 1.003280
# Epoch    8/10 W: 0.999, Cost: 0.998690
# Epoch    9/10 W: 1.000, Cost: 1.000525
# Epoch   10/10 W: 1.000, Cost: 0.999790

# %%
import torch.optim as optim

# optimizer 설정 : learning rate parameter vlftn!
optimizer = optim.SGD([W], lr=0.15)

# cost로 H(X) 개선
optimizer.zero_grad() # gradient를 0으로 초기화
cost.backward() # gradient 계산
optimizer.step() # gradient descent

# %%
#데이터
x_train = torch.FloatTensor([[1],[2],[3]])
y_train = torch.FloatTensor([[1],[2],[3]])

#모델 초기화
W = torch.zeros(1)

#optimizer 설정
optimizer = optim.SGD([W], lr=0.15)

nb_epochs = 10
for epoch in range(nb_epochs + 1):
    
    # H(x) 계산
    hypothesis = x_train + W
    
    # cost gradient 계산
    cost = torch.mean((hypothesis - y_train)**2)
    
    print("Epoch {:4d}/10 W: {:.3f} Cost: {:.6f}".format(epoch, W.item(), cost.item()))
# Out:
# Epoch    0/10 W: 0.000 Cost: 0.000000
# Epoch    1/10 W: 0.000 Cost: 0.000000
# Epoch    2/10 W: 0.000 Cost: 0.000000
# Epoch    3/10 W: 0.000 Cost: 0.000000
# Epoch    4/10 W: 0.000 Cost: 0.000000
# Epoch    5/10 W: 0.000 Cost: 0.000000
# Epoch    6/10 W: 0.000 Cost: 0.000000
# Epoch    7/10 W: 0.000 Cost: 0.000000
# Epoch    8/10 W: 0.000 Cost: 0.000000
# Epoch    9/10 W: 0.000 Cost: 0.000000
# Epoch   10/10 W: 0.000 Cost: 0.000000
