# %%
import matplotlib.pyplot as plt

customers = ['ABC', 'DEF', 'GHI', 'JKL', 'MNO']
customers_index = range(len(customers))
sale_amounts = [123, 90, 201, 111, 232]

fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax1.bar(customers_index, sale_amounts, align='center', color='darkblue')

plt.xticks(customers_index, customers, rotation=0, fontsize='small')
plt.xlabel('Customer Name')
plt.ylabel('Sale Amount')
plt.title('Sale Amount per Customer')

ax2 = fig.add_subplot(1,2,2)

plt.show()

# %%
import numpy as np

fig = plt.figure()
ax1 = fig.add_subplot(2,1,1);
x = np.linspace(0,10);
y1 = np.sin(x);
ax1.plot(x,y1)

ax2 = fig.add_subplot(2,1,2); 
y2 = np.sin(5*x);
ax2.plot(x,y2)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
x = np.linspace(-3.8,3.8)
y_cos = np.cos(x)
ax1.plot(x,y_cos)
plt.title('Subplot 1: Cosine')

ax2 = fig.add_subplot(2,2,2)
y_poly = 1 - x**(2/2) + x**(4/24)
ax2.plot(x,y_poly,'g')
plt.title('Subplot 2: Polynomial')

ax3 = fig.add_subplot(2,2,(3,4))
ax3.plot(x,y_cos,'b',x,y_poly,'g')
plt.title('Subplot 3 and 4: Both')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in power
#   if __name__ == '__main__':
# Text(0.5, 1.0, 'Subplot 3 and 4: Both')
